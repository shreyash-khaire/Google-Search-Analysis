# %%
import pandas as pd 
from pytrends.request import TrendReq 
import matplotlib.pyplot as plt 
Trending_topics = TrendReq(hl='en-US', tz=360)

# %%
kw_list=["Data Analytics"] 
Trending_topics.build_payload(kw_list,cat=0, timeframe='today 12-m')

# %%
Trending_topics.build_payload(kw_list=["Data Analytics"], cat=0, timeframe='today 12-m') 							
data = Trending_topics.interest_over_time() 
data = data.sort_values(by="Data Analytics", ascending = False) 
data = data.head(10) 
print(data)
pd.set_option('future.no_silent_downcasting', True)
data=data.fillna(False)
# Out:
#             Data Analytics  isPartial
# date
# 2024-02-18             100      False
# 2024-02-25              98      False
# 2024-01-28              96      False
# 2024-06-23              94      False
# 2024-03-17              94      False
# 2024-02-11              94      False
# 2024-04-21              93      False
# 2023-09-17              93      False
# 2024-02-04              92      False
# 2024-07-14              92      False

# %%
data = Trending_topics.interest_by_region() 
data = data.sort_values(by="Data Analytics", ascending = False) 
data = data.head(20) 
print(data)
# Out:
#                Data Analytics
# geoName
# Zimbabwe                  100
# Singapore                  88
# St. Helena                 69
# Ghana                      68
# Nigeria                    62
# Kenya                      61
# India                      54
# South Korea                50
# Ethiopia                   42
# Sri Lanka                  36
# Pakistan                   34
# Ireland                    34
# Nepal                      33
# China                      31
# Canada                     31
# South Africa               29
# Malaysia                   28
# Hong Kong                  28
# Australia                  27
# United States              27

# %%
data.reset_index().plot(x='geoName', y='Data Analytics', figsize=(10,5), kind="bar") 					
plt.style.use('fivethirtyeight') 
plt.show()

# %%
df = Trending_topics.top_charts(2020, hl='en-US', tz=300, geo='GLOBAL') 							
df.head(20)
# Out:
#                   title exploreQuery
# 0           Coronavirus
# 1      Election results
# 2           Kobe Bryant
# 3                  Zoom
# 4                   IPL
# 5  India vs New Zealand
# 6    Coronavirus update
# 7  Coronavirus symptoms
# 8             Joe Biden
# 9      Google Classroom

# %%
keywords = Trending_topics.suggestions( keyword='Data Analytics') 
df = pd.DataFrame(keywords) 
df.drop(columns= 'mid')
# Out:
#                                                title  \
# 0                                          Analytics
# 1                           Python for Data Analysis
# 2                   Fundamentals of Data Engineering
# 3  Competing in the Age of AI: Strategy and Leade...
# 4                             American Democracy Now
#
#                                                 type
# 0                                              Topic
# 1                               Book by Wes McKinney
# 2                  Book by Joe Reis and Matt Housley
# 3         Book by Karim R. Lakhani and Marco Iansiti
# 4  Book by Brigid C. Harrison, Jean Harris, and M...

# %%
df=Trending_topics.trending_searches(pn="india")
df.head(10)
# Out:
#                                           0
# 0                Krishna Janmashtami images
# 1  Orient Technologies IPO allotment status
# 2                         Minu Muneer actor
# 3                              Rahul Gandhi
# 4                             Narendra Modi
# 5                                   US Open
# 6                          Vasantrao Chavan
# 7                      Premier Energies IPO
# 8                                   Baburaj
# 9                     International Dog Day
